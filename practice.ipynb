# %% [markdown]
# <a href="https://colab.research.google.com/github/youreyesarecameras-dot/jeremiahpracticeexrcise1/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#even or odd?
number = int(input("Input a number of your choice: "))

if number % 2 == 0:
  print("Your number is even")
else:
  print("Your number is odd")
# Out:
# Input a number of your choice: 5
# Your number is odd

# %%
#Even or odd?
##Input a number
##The program will return even or odd
# Out:
# Input a number of your choice: 5
# Your number is odd
